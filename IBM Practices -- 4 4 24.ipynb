# %%
# Thalaiva
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("auto.csv")

# %%
# nEw data with new modules

# %%
data_frame_sales = pd.read_csv("auto.csv")

# %%
data_frame_sales.head(5)
# Out:
#    3    ?  alfa-romero  gas  std   two  convertible  rwd  front  88.6  ...  \
# 0  3    ?  alfa-romero  gas  std   two  convertible  rwd  front  88.6  ...
# 1  1    ?  alfa-romero  gas  std   two    hatchback  rwd  front  94.5  ...
# 2  2  164         audi  gas  std  four        sedan  fwd  front  99.8  ...
# 3  2  164         audi  gas  std  four        sedan  4wd  front  99.4  ...
# 4  2    ?         audi  gas  std   two        sedan  fwd  front  99.8  ...
#
#    130  mpfi  3.47  2.68   9.0  111  5000  21  27  13495
# 0  130  mpfi  3.47  2.68   9.0  111  5000  21  27  16500
# 1  152  mpfi  2.68  3.47   9.0  154  5000  19  26  16500
# 2  109  mpfi  3.19  3.40  10.0  102  5500  24  30  13950
# 3  136  mpfi  3.19  3.40   8.0  115  5500  18  22  17450
# 4  136  mpfi  3.19  3.40   8.5  110  5500  19  25  15250
#
# [5 rows x 26 columns]

# %%
# create headers list
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]
print("headers\n", headers)
# Out:
# headers
#  ['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration', 'num-of-doors', 'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price']

# %%
data_frame_sales.columns = headers

# %%
data_frame_sales
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            1                 ?  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2                 ?         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                95        volvo       gas        std
# 200         -1                95        volvo       gas      turbo
# 201         -1                95        volvo       gas        std
# 202         -1                95        volvo    diesel      turbo
# 203         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
data_frame_sales.replace("?", np.NaN,inplace= True)

# %%
data_frame_sales
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               NaN  alfa-romero       gas        std
# 1            1               NaN  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2               NaN         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                95        volvo       gas        std
# 200         -1                95        volvo       gas      turbo
# 201         -1                95        volvo       gas        std
# 202         -1                95        volvo    diesel      turbo
# 203         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
data_frame_sales.isnull()
# Out:
#      symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0        False               True  False      False       False         False
# 1        False               True  False      False       False         False
# 2        False              False  False      False       False         False
# 3        False              False  False      False       False         False
# 4        False               True  False      False       False         False
# ..         ...                ...    ...        ...         ...           ...
# 199      False              False  False      False       False         False
# 200      False              False  False      False       False         False
# 201      False              False  False      False       False         False
# 202      False              False  False      False       False         False
# 203      False              False  False      False       False         False
#
# ...

# %%
data_frame_sales.notnull()
# Out:
#      symboling  normalized-losses  make  fuel-type  aspiration  num-of-doors  \
# 0         True              False  True       True        True          True
# 1         True              False  True       True        True          True
# 2         True               True  True       True        True          True
# 3         True               True  True       True        True          True
# 4         True              False  True       True        True          True
# ..         ...                ...   ...        ...         ...           ...
# 199       True               True  True       True        True          True
# 200       True               True  True       True        True          True
# 201       True               True  True       True        True          True
# 202       True               True  True       True        True          True
# 203       True               True  True       True        True          True
#
# ...

# %%
missing_df = data_frame_sales.isnull()
missing_df.head(5)
# Out:
#    symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0      False               True  False      False       False         False
# 1      False               True  False      False       False         False
# 2      False              False  False      False       False         False
# 3      False              False  False      False       False         False
# 4      False               True  False      False       False         False
#
#    body-style  drive-wheels  engine-location  wheel-base  ...  engine-size  \
# 0       False         False            False       False  ...        False
# 1       False         False            False       False  ...        False
# 2       False         False            False       False  ...        False
# 3       False         False            False       False  ...        False
# 4       False         False            False       False  ...        False
#
# ...

# %%
for columns in missing_df.columns.values:
    print(columns)
# Out:
# symboling
# normalized-losses
# make
# fuel-type
# aspiration
# num-of-doors
# body-style
# drive-wheels
# engine-location
# wheel-base
# length
# width
# height
# curb-weight
# engine-type
# num-of-cylinders
# engine-size
# fuel-system
# bore
# stroke
# compression-ratio
# horsepower
# peak-rpm
# city-mpg
# highway-mpg
# price

# %%
for columns in missing_df.columns.values:
    print(missing_df[columns].value_counts())
    print("")
# Out:
# symboling
# False    204
# Name: count, dtype: int64
#
# normalized-losses
# False    164
# True      40
# Name: count, dtype: int64
#
# make
# False    204
# Name: count, dtype: int64
#
# fuel-type
# False    204
# Name: count, dtype: int64
#
# aspiration
# False    204
# Name: count, dtype: int64
#
# num-of-doors
# False    202
# True       2
# Name: count, dtype: int64
#
# body-style
# False    204
# Name: count, dtype: int64
#
# drive-wheels
# False    204
# Name: count, dtype: int64
#
# engine-location
# False    204
# Name: count, dtype: int64
#
# wheel-base
# False    204
# Name: count, dtype: int64
#
# length
# False    204
# Name: count, dtype: int64
#
# width
# False    204
# Name: count, dtype: int64
#
# height
# False    204
# Name: count, dtype: int64
#
# curb-weight
# False    204
# Name: count, dtype: int64
#
# engine-type
# False    204
# Name: count, dtype: int64
#
# num-of-cylinders
# False    204
# Name: count, dtype: int64
#
# engine-size
# False    204
# ...

# %%
for columns in missing_df.columns.values.tolist():
    print(missing_df[columns].value_counts())
    print("")
# Out:
# symboling
# False    204
# Name: count, dtype: int64
#
# normalized-losses
# False    164
# True      40
# Name: count, dtype: int64
#
# make
# False    204
# Name: count, dtype: int64
#
# fuel-type
# False    204
# Name: count, dtype: int64
#
# aspiration
# False    204
# Name: count, dtype: int64
#
# num-of-doors
# False    202
# True       2
# Name: count, dtype: int64
#
# body-style
# False    204
# Name: count, dtype: int64
#
# drive-wheels
# False    204
# Name: count, dtype: int64
#
# engine-location
# False    204
# Name: count, dtype: int64
#
# wheel-base
# False    204
# Name: count, dtype: int64
#
# length
# False    204
# Name: count, dtype: int64
#
# width
# False    204
# Name: count, dtype: int64
#
# height
# False    204
# Name: count, dtype: int64
#
# curb-weight
# False    204
# Name: count, dtype: int64
#
# engine-type
# False    204
# Name: count, dtype: int64
#
# num-of-cylinders
# False    204
# Name: count, dtype: int64
#
# engine-size
# False    204
# ...

# %%
data_frame_sales.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  204.000000  204.000000  204.000000  204.000000  204.000000
# mean     0.823529   98.806373  174.075000   65.916667   53.749020
# std      1.239035    5.994144   12.362123    2.146716    2.424901
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.075000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.200000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   204.000000   204.000000         204.000000  204.000000   204.000000
# mean   2555.602941   126.892157          10.148137   25.240196    30.769608
# std     521.960820    41.744569           3.981000    6.551513     6.898337
# ...

# %%
data_frame_sales["normalized-losses"].astype("float").mean(axis = 0)
# Out:
# 122.0

# %%
type(data_frame_sales["normalized-losses"])
# Out:
# pandas.core.series.Series

# %%
data_frame_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          204 non-null    int64
#  1   normalized-losses  164 non-null    object
#  2   make               204 non-null    object
#  3   fuel-type          204 non-null    object
#  4   aspiration         204 non-null    object
#  5   num-of-doors       202 non-null    object
#  6   body-style         204 non-null    object
#  7   drive-wheels       204 non-null    object
#  8   engine-location    204 non-null    object
#  9   wheel-base         204 non-null    float64
#  10  length             204 non-null    float64
#  11  width              204 non-null    float64
#  12  height             204 non-null    float64
#  13  curb-weight        204 non-null    int64
#  14  engine-type        204 non-null    object
#  15  num-of-cylinders   204 non-null    object
# ...

# %%
# Need to change the type of df["normalized-losses"] cause its in object we need to change that.

# %%
# data_frame_sales['normalized-losses'].mean() ---> Error of type conver
data_frame_sales["normalized-losses"].astype(float).mean()
# Out:
# 122.0

# %%
required_mean_normalized = data_frame_sales["normalized-losses"].astype(float).mean()
#data_frame_sales["normalized-losses"].replace("Nan", required_mean_normalized)# Wrong becaause of NAN should not be in string istead of we should give np.nan

data_frame_sales["normalized-losses"].replace(np.nan, required_mean_normalized ,inplace=True)

# %%
data_frame_sales[data_frame_sales['normalized-losses'].isnull()] # as of now there is no null vlaues
# Out:
# Empty DataFrame
# Columns: [symboling, normalized-losses, make, fuel-type, aspiration, num-of-doors, body-style, drive-wheels, engine-location, wheel-base, length, width, height, curb-weight, engine-type, num-of-cylinders, engine-size, fuel-system, bore, stroke, compression-ratio, horsepower, peak-rpm, city-mpg, highway-mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
data_frame_sales[data_frame_sales['num-of-doors'].isnull()]
# Out:
#     symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 26          1               148  dodge       gas      turbo          NaN
# 62          0             122.0  mazda    diesel        std          NaN
#
#    body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 26      sedan          fwd           front        93.7  ...           98
# 62      sedan          fwd           front        98.8  ...          122
#
#     fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 26         mpfi  3.03    3.39               7.6        102      5500       24
# 62          idi  3.39    3.39              22.7         64      4650       36
#
#    highway-mpg  price
# 26          30   8558
# 62          42  10795
#
# [2 rows x 26 columns]

# %%
# Similarlly gonna do following 4

# %%
#normalized-losses": 41 missing data, replace them with mean
# "stroke": 4 missing data, replace them with mean
# "bore": 4 missing data, replace them with mean
# "horsepower": 2 missing data, replace them with mean
# "peak-rpm": 2 missing data, replace them with mean

# %%
data_frame_sales[data_frame_sales['bore'].isnull()]
# Out:
#     symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 54          3               150  mazda       gas        std          two
# 55          3               150  mazda       gas        std          two
# 56          3               150  mazda       gas        std          two
# 57          3               150  mazda       gas        std          two
#
#    body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 54  hatchback          rwd           front        95.3  ...           70
# 55  hatchback          rwd           front        95.3  ...           70
# 56  hatchback          rwd           front        95.3  ...           70
# 57  hatchback          rwd           front        95.3  ...           80
#
#     fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 54         4bbl   NaN     NaN               9.4        101      6000       17
# ...

# %%
data_frame_sales['bore'].replace(np.nan,data_frame_sales['bore'].astype(float).mean(),inplace=True)

# %%
data_frame_sales[data_frame_sales['bore'].isnull()]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized-losses, make, fuel-type, aspiration, num-of-doors, body-style, drive-wheels, engine-location, wheel-base, length, width, height, curb-weight, engine-type, num-of-cylinders, engine-size, fuel-system, bore, stroke, compression-ratio, horsepower, peak-rpm, city-mpg, highway-mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
data_frame_sales[data_frame_sales['stroke'].isnull()]
# Out:
#     symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 54          3               150  mazda       gas        std          two
# 55          3               150  mazda       gas        std          two
# 56          3               150  mazda       gas        std          two
# 57          3               150  mazda       gas        std          two
#
#    body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 54  hatchback          rwd           front        95.3  ...           70
# 55  hatchback          rwd           front        95.3  ...           70
# 56  hatchback          rwd           front        95.3  ...           70
# 57  hatchback          rwd           front        95.3  ...           80
#
#     fuel-system     bore  stroke compression-ratio horsepower  peak-rpm  \
# 54         4bbl  3.32905     NaN               9.4        101      6000
# 55         4bbl  3.32905     NaN               9.4        101      6000
# ...

# %%
data_frame_sales["stroke"].replace(np.nan,data_frame_sales['stroke'].astype(float).mean(),inplace = True)

# %%
data_frame_sales[data_frame_sales['stroke'].isnull()]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized-losses, make, fuel-type, aspiration, num-of-doors, body-style, drive-wheels, engine-location, wheel-base, length, width, height, curb-weight, engine-type, num-of-cylinders, engine-size, fuel-system, bore, stroke, compression-ratio, horsepower, peak-rpm, city-mpg, highway-mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
data_frame_sales["horsepower"].replace(np.nan,data_frame_sales['horsepower'].astype(float).mean(),inplace = True)

# %%
data_frame_sales["peak-rpm"].replace(np.nan,data_frame_sales['peak-rpm'].astype(float).mean(),inplace = True)

# %%
data_frame_sales[data_frame_sales['peak-rpm'].isnull()]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized-losses, make, fuel-type, aspiration, num-of-doors, body-style, drive-wheels, engine-location, wheel-base, length, width, height, curb-weight, engine-type, num-of-cylinders, engine-size, fuel-system, bore, stroke, compression-ratio, horsepower, peak-rpm, city-mpg, highway-mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
data_frame_sales[data_frame_sales['horsepower'].isnull()]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized-losses, make, fuel-type, aspiration, num-of-doors, body-style, drive-wheels, engine-location, wheel-base, length, width, height, curb-weight, engine-type, num-of-cylinders, engine-size, fuel-system, bore, stroke, compression-ratio, horsepower, peak-rpm, city-mpg, highway-mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
# Mean is completed now we are gonna try the frequency factors

# %% [markdown]
# Now we are gonna try the frequency method in here to get the most used object and replace them with nan

# %% [markdown]
# "num-of-doors": 2 missing data, replace them with "four".
# Reason: 84% sedans are four doors. Since four doors is most frequent, it is most likely to occur

# %%
data_frame_sales[data_frame_sales["num-of-doors"].isnull()]
# Out:
#     symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 26          1               148  dodge       gas      turbo          NaN
# 62          0             122.0  mazda    diesel        std          NaN
#
#    body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 26      sedan          fwd           front        93.7  ...           98
# 62      sedan          fwd           front        98.8  ...          122
#
#     fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 26         mpfi  3.03    3.39               7.6        102      5500       24
# 62          idi  3.39    3.39              22.7         64      4650       36
#
#    highway-mpg  price
# 26          30   8558
# 62          42  10795
#
# [2 rows x 26 columns]

# %%
data_frame_sales["num-of-doors"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 204 entries, 0 to 203
# Series name: num-of-doors
# Non-Null Count  Dtype
# --------------  -----
# 202 non-null    object
# dtypes: object(1)
# memory usage: 1.7+ KB

# %%
data_frame_sales["num-of-doors"].astype(str).max()# ---->Check it
# Out:
# 'two'

# %%
data_frame_sales["num-of-doors"].value_counts().idxmax()
# Out:
# 'four'

# %%
# Replacing them

# %%
data_frame_sales["num-of-doors"].replace(np.nan,data_frame_sales["num-of-doors"].value_counts().idxmax(),inplace= True)

# %%
data_frame_sales[data_frame_sales['num-of-doors'].isnull()]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized-losses, make, fuel-type, aspiration, num-of-doors, body-style, drive-wheels, engine-location, wheel-base, length, width, height, curb-weight, engine-type, num-of-cylinders, engine-size, fuel-system, bore, stroke, compression-ratio, horsepower, peak-rpm, city-mpg, highway-mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
# Now we are gonna drop the data's in price

# %%
data_frame_sales.dropna(subset=["price"],axis = 0, inplace=True)

# %%
data_frame_sales
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3             122.0  alfa-romero       gas        std
# 1            1             122.0  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2             122.0         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                95        volvo       gas        std
# 200         -1                95        volvo       gas      turbo
# 201         -1                95        volvo       gas        std
# 202         -1                95        volvo    diesel      turbo
# 203         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
data_frame_sales.reset_index(drop= True,inplace=True)

# %%
data_frame_sales
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3             122.0  alfa-romero       gas        std
# 1            1             122.0  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2             122.0         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 195         -1                95        volvo       gas        std
# 196         -1                95        volvo       gas      turbo
# 197         -1                95        volvo       gas        std
# 198         -1                95        volvo    diesel      turbo
# 199         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
# 17 - 04 - 2024

# %%
#Correcting the data types of the table as proper way

# %%
data_frame_sales.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
#18-04-24

# %%
#Need to change the data types for the following some

# %%
data_frame_sales[["bore","stroke"]].dtypes
# Out:
# bore      object
# stroke    object
# dtype: object

# %%
data_frame_sales[["bore","stroke"]].astype(float).dtypes
# Out:
# bore      float64
# stroke    float64
# dtype: object

# %%
#Need to save

# %%
data_frame_sales[["bore","stroke"]] = data_frame_sales[["bore","stroke"]].astype("float")

# %%
data_frame_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          200 non-null    int64
#  1   normalized-losses  200 non-null    object
#  2   make               200 non-null    object
#  3   fuel-type          200 non-null    object
#  4   aspiration         200 non-null    object
#  5   num-of-doors       200 non-null    object
#  6   body-style         200 non-null    object
#  7   drive-wheels       200 non-null    object
#  8   engine-location    200 non-null    object
#  9   wheel-base         200 non-null    float64
#  10  length             200 non-null    float64
#  11  width              200 non-null    float64
#  12  height             200 non-null    float64
#  13  curb-weight        200 non-null    int64
#  14  engine-type        200 non-null    object
#  15  num-of-cylinders   200 non-null    object
# ...

# %%
data_frame_sales[["normalized-losses"]] = data_frame_sales[["normalized-losses"]].astype(int)

# %%
data_frame_sales[["peak-rpm","price"]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   peak-rpm  200 non-null    object
#  1   price     200 non-null    object
# dtypes: object(2)
# memory usage: 3.3+ KB

# %%
data_frame_sales[["peak-rpm","price"]] = data_frame_sales[["peak-rpm","price"]].astype(float)

# %%
data_frame_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          200 non-null    int64
#  1   normalized-losses  200 non-null    int32
#  2   make               200 non-null    object
#  3   fuel-type          200 non-null    object
#  4   aspiration         200 non-null    object
#  5   num-of-doors       200 non-null    object
#  6   body-style         200 non-null    object
#  7   drive-wheels       200 non-null    object
#  8   engine-location    200 non-null    object
#  9   wheel-base         200 non-null    float64
#  10  length             200 non-null    float64
#  11  width              200 non-null    float64
#  12  height             200 non-null    float64
#  13  curb-weight        200 non-null    int64
#  14  engine-type        200 non-null    object
#  15  num-of-cylinders   200 non-null    object
# ...

# %% [markdown]
# Data Standardization

# %%
data_frame_sales.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          1                122  alfa-romero       gas        std
# 2          2                164         audi       gas        std
# 3          2                164         audi       gas        std
# 4          2                122         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two    hatchback          rwd           front        94.5  ...
# 2         four        sedan          fwd           front        99.8  ...
# 3         four        sedan          4wd           front        99.4  ...
# 4          two        sedan          fwd           front        99.8  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
# Convert mpg to L/100km by mathematical operation (235 divided by mpg)
data_frame_sales['city-L/100km'] = 235/data_frame_sales["city-mpg"]

# check your transformed data 
data_frame_sales.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          1                122  alfa-romero       gas        std
# 2          2                164         audi       gas        std
# 3          2                164         audi       gas        std
# 4          2                122         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two    hatchback          rwd           front        94.5  ...
# 2         four        sedan          fwd           front        99.8  ...
# 3         four        sedan          4wd           front        99.4  ...
# 4          two        sedan          fwd           front        99.8  ...
#
#    fuel-system  bore  stroke  compression-ratio horsepower peak-rpm  city-mpg  \
# ...

# %%
# Similarlly we need to do it for highway L/100
data_frame_sales['highway-L/100km'] = 235/data_frame_sales["highway-mpg"]

# check your transformed data 
data_frame_sales.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          1                122  alfa-romero       gas        std
# 2          2                164         audi       gas        std
# 3          2                164         audi       gas        std
# 4          2                122         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two    hatchback          rwd           front        94.5  ...
# 2         four        sedan          fwd           front        99.8  ...
# 3         four        sedan          4wd           front        99.4  ...
# 4          two        sedan          fwd           front        99.8  ...
#
#    bore  stroke  compression-ratio  horsepower peak-rpm city-mpg  highway-mpg  \
# ...

# %% [markdown]
# ##**Data Normalization
# Why normalization?**##
#
# Normalization is the process of transforming values of several variables into a similar range. Typical normalizations include
#
# scaling the variable so the variable average is 0
# scaling the variable so the variance is 1
# scaling the variable so the variable values range from 0 to 1

# %%
# replace (original value) by (original value)/(maximum value)
data_frame_sales['length'] = data_frame_sales['length']/data_frame_sales['length'].max()
data_frame_sales['width'] = data_frame_sales['width']/data_frame_sales['width'].max()

# %%
data_frame_sales
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                122  alfa-romero       gas        std
# 1            1                122  alfa-romero       gas        std
# 2            2                164         audi       gas        std
# 3            2                164         audi       gas        std
# 4            2                122         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 195         -1                 95        volvo       gas        std
# 196         -1                 95        volvo       gas      turbo
# 197         -1                 95        volvo       gas        std
# 198         -1                 95        volvo    diesel      turbo
# 199         -1                 95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
data_frame_sales["length"]
# Out:
# 0      0.811148
# 1      0.822681
# 2      0.848630
# 3      0.848630
# 4      0.851994
#          ...
# 195    0.907256
# 196    0.907256
# 197    0.907256
# 198    0.907256
# 199    0.907256
# Name: length, Length: 200, dtype: float64

# %%
data_frame_sales["width"]
# Out:
# 0      0.890278
# 1      0.909722
# 2      0.919444
# 3      0.922222
# 4      0.920833
#          ...
# 195    0.956944
# 196    0.955556
# 197    0.956944
# 198    0.956944
# 199    0.956944
# Name: width, Length: 200, dtype: float64

# %%
data_frame_sales["height"]
# Out:
# 0      48.8
# 1      52.4
# 2      54.3
# 3      54.3
# 4      53.1
#        ...
# 195    55.5
# 196    55.5
# 197    55.5
# 198    55.5
# 199    55.5
# Name: height, Length: 200, dtype: float64

# %%
data_frame_sales['height'] = data_frame_sales['height']/data_frame_sales['height'].max()

# %%
data_frame_sales["height"]
# Out:
# 0      0.816054
# 1      0.876254
# 2      0.908027
# 3      0.908027
# 4      0.887960
#          ...
# 195    0.928094
# 196    0.928094
# 197    0.928094
# 198    0.928094
# 199    0.928094
# Name: height, Length: 200, dtype: float64

# %%
data_frame_sales
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                122  alfa-romero       gas        std
# 1            1                122  alfa-romero       gas        std
# 2            2                164         audi       gas        std
# 3            2                164         audi       gas        std
# 4            2                122         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 195         -1                 95        volvo       gas        std
# 196         -1                 95        volvo       gas      turbo
# 197         -1                 95        volvo       gas        std
# 198         -1                 95        volvo    diesel      turbo
# 199         -1                 95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
#binning

# %% [markdown]
# Why binning?
#
# Binning is a process of transforming continuous numerical variables into discrete categorical 'bins' for grouped analysis.
#
# Example:
#
# In your data set, "horsepower" is a real valued variable ranging from 48 to 288 and it has 59 unique values. What if you only care about the price difference between cars with high horsepower, medium horsepower, and little horsepower (3 types)? You can rearrange them into three ‘bins' to simplify analysis.
#
# Use the Pandas method 'cut' to segment the 'horsepower' column into 3 bins

# %%
#example 
import pandas as pd

data = [1, 5, 10, 15, 20, 25, 30, 35, 40]
bins = pd.cut(data, bins=4)  # Create 4 equal-width bins
print(bins)
# Out:
# [(0.961, 10.75], (0.961, 10.75], (0.961, 10.75], (10.75, 20.5], (10.75, 20.5], (20.5, 30.25], (20.5, 30.25], (30.25, 40.0], (30.25, 40.0]]
# Categories (4, interval[float64, right]): [(0.961, 10.75] < (10.75, 20.5] < (20.5, 30.25] < (30.25, 40.0]]

# %%
del data

# %%
data_frame_sales["horsepower"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 200 entries, 0 to 199
# Series name: horsepower
# Non-Null Count  Dtype
# --------------  -----
# 200 non-null    object
# dtypes: object(1)
# memory usage: 1.7+ KB

# %%
data_frame_sales["horsepower"]=data_frame_sales["horsepower"].astype(int, copy=True)

# %%
data_frame_sales["horsepower"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 200 entries, 0 to 199
# Series name: horsepower
# Non-Null Count  Dtype
# --------------  -----
# 200 non-null    int32
# dtypes: int32(1)
# memory usage: 932.0 bytes

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
plt.pyplot.hist(data_frame_sales["horsepower"])

# set x/y labels and plot title
plt.pyplot.xlabel("horsepower")
plt.pyplot.ylabel("count")
plt.pyplot.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %%
# Need to create bins for horse power!!

# %%
bins = np.linspace(min(data_frame_sales["horsepower"]), max(data_frame_sales["horsepower"]), 4)
bins
# Out:
# array([ 48.        , 119.33333333, 190.66666667, 262.        ])

# %%
group_names = ['Low', 'Medium', 'High']

# %%
data_frame_sales['horsepower-binned'] = pd.cut(data_frame_sales['horsepower'], bins, labels=group_names, include_lowest=True )

# %%
data_frame_sales[['horsepower','horsepower-binned']].head(20)
# Out:
#     horsepower horsepower-binned
# 0          111               Low
# 1          154            Medium
# 2          102               Low
# 3          115               Low
# 4          110               Low
# 5          110               Low
# 6          110               Low
# 7          140            Medium
# 8          101               Low
# 9          101               Low
# 10         121            Medium
# 11         121            Medium
# 12         121            Medium
# 13         182            Medium
# 14         182            Medium
# 15         182            Medium
# 16          48               Low
# 17          70               Low
# 18          70               Low
# 19          68               Low

# %%
data_frame_sales[data_frame_sales["horsepower-binned"] == "High"]
# Out:
#      symboling  normalized-losses     make fuel-type aspiration num-of-doors  \
# 45           0                122   jaguar       gas        std          two
# 101          3                194   nissan       gas      turbo          two
# 122          3                122  porsche       gas        std          two
# 123          3                122  porsche       gas        std          two
# 124          3                122  porsche       gas        std          two
#
#       body-style drive-wheels engine-location  wheel-base  ...  stroke  \
# 45         sedan          rwd           front       102.0  ...    2.76
# 101    hatchback          rwd           front        91.3  ...    3.27
# 122      hardtop          rwd            rear        89.5  ...    2.90
# 123      hardtop          rwd            rear        89.5  ...    2.90
# 124  convertible          rwd            rear        89.5  ...    2.90
#
# ...

# %%
# 19-07-24

# %%
data_frame_sales
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                122  alfa-romero       gas        std
# 1            1                122  alfa-romero       gas        std
# 2            2                164         audi       gas        std
# 3            2                164         audi       gas        std
# 4            2                122         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 195         -1                 95        volvo       gas        std
# 196         -1                 95        volvo       gas      turbo
# 197         -1                 95        volvo       gas        std
# 198         -1                 95        volvo    diesel      turbo
# 199         -1                 95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %% [markdown]
# ## Indicator Variable
#
# **What is an indicator variable?**
#
# An indicator variable (or dummy variable) is a numerical variable used to label categories. They are called 'dummies' because the numbers themselves don't have inherent meaning.
#
# Why use indicator variables?
#
# You use indicator variables so you can use categorical variables for regression analysis in the later modules.
#
# Example

# %%
# Fuel type in data should not be word by which data can't understand properly

# %%
data_frame_sales["fuel-type"].tail(10)
# Out:
# 190       gas
# 191       gas
# 192       gas
# 193       gas
# 194       gas
# 195       gas
# 196       gas
# 197       gas
# 198    diesel
# 199       gas
# Name: fuel-type, dtype: object

# %%
data_frame_sales.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price', 'city-L/100km', 'highway-L/100km',
#        'horsepower-binned'],
#       dtype='object')

# %% [markdown]
# <b>pd.get_dummies() \n
# is a function in pandas used for one-hot encoding categorical variables. One-hot encoding is a process of converting categorical variables into a binary format where each category is represented as a binary vector.

# %%
dummy_var_ = pd.get_dummies(data_frame_sales["fuel-type"])

# %%
dummy_var_.tail(10)
# Out:
#      diesel    gas
# 190   False   True
# 191   False   True
# 192   False   True
# 193   False   True
# 194   False   True
# 195   False   True
# 196   False   True
# 197   False   True
# 198    True  False
# 199   False   True

# %%
# we will change the col names for our understanding

# %%
dummy_var_.rename(columns={"diesel" : "fuel-type-diesel","gas" : "fuel-type-gas"},inplace=True)

# %%
dummy_var_.tail(10)
# Out:
#      fuel-type-diesel  fuel-type-gas
# 190             False           True
# 191             False           True
# 192             False           True
# 193             False           True
# 194             False           True
# 195             False           True
# 196             False           True
# 197             False           True
# 198              True          False
# 199             False           True

# %%
# merge data frame "df" and "dummy_variable_1" 
data_frame_sales = pd.concat([data_frame_sales, dummy_var_], axis=1)

# %%
data_frame_sales
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                122  alfa-romero       gas        std
# 1            1                122  alfa-romero       gas        std
# 2            2                164         audi       gas        std
# 3            2                164         audi       gas        std
# 4            2                122         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 195         -1                 95        volvo       gas        std
# 196         -1                 95        volvo       gas      turbo
# 197         -1                 95        volvo       gas        std
# 198         -1                 95        volvo    diesel      turbo
# 199         -1                 95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
# drop original column "fuel-type" from "df"
data_frame_sales.drop("fuel-type", axis = 1, inplace=True)

# %%
data_frame_sales
# Out:
#      symboling  normalized-losses         make aspiration num-of-doors  \
# 0            3                122  alfa-romero        std          two
# 1            1                122  alfa-romero        std          two
# 2            2                164         audi        std         four
# 3            2                164         audi        std         four
# 4            2                122         audi        std          two
# ..         ...                ...          ...        ...          ...
# 195         -1                 95        volvo        std         four
# 196         -1                 95        volvo      turbo         four
# 197         -1                 95        volvo        std         four
# 198         -1                 95        volvo      turbo         four
# 199         -1                 95        volvo      turbo         four
#
#       body-style drive-wheels engine-location  wheel-base    length  ...  \
# ...

# %%
# Similarlly we need to do it for aspiration

# %%
dummy_var_aspiration = pd.get_dummies(data= data_frame_sales["aspiration"])

# %%
dummy_var_aspiration.rename(columns={"std":"aspiration-type-std","turbo":"aspiration-type-turbo"},inplace=True)

# %%
dummy_var_aspiration
# Out:
#      aspiration-type-std  aspiration-type-turbo
# 0                   True                  False
# 1                   True                  False
# 2                   True                  False
# 3                   True                  False
# 4                   True                  False
# ..                   ...                    ...
# 195                 True                  False
# 196                False                   True
# 197                 True                  False
# 198                False                   True
# 199                False                   True
#
# [200 rows x 2 columns]

# %%
# merge data frame "df" and "dummy_variable_aspiration" 
data_frame_sales = pd.concat([data_frame_sales,dummy_var_aspiration],axis=1)

# %%
# drop original column "fuel-type" from "df"
data_frame_sales.drop("aspiration", axis = 1, inplace=True)

# %%
data_frame_sales
# Out:
#      symboling  normalized-losses         make num-of-doors   body-style  \
# 0            3                122  alfa-romero          two  convertible
# 1            1                122  alfa-romero          two    hatchback
# 2            2                164         audi         four        sedan
# 3            2                164         audi         four        sedan
# 4            2                122         audi          two        sedan
# ..         ...                ...          ...          ...          ...
# 195         -1                 95        volvo         four        sedan
# 196         -1                 95        volvo         four        sedan
# 197         -1                 95        volvo         four        sedan
# 198         -1                 95        volvo         four        sedan
# 199         -1                 95        volvo         four        sedan
#
#     drive-wheels engine-location  wheel-base    length     width  ...  \
# ...

# %%
data_frame_sales.to_csv("clean_data_frame_sales.csv")

# %%
# Thats the end of Data Wrangling

# %% [markdown]
# * Identify and handle missing values
# * Identify missing values
# * Deal with missing values
# * Correct data format
# * Data standardization
# * Data normalization (centering/scaling)
# * Binning
# * Indicator variable

# %%
# In Data Wrangling we need to do all these to cleaning up the data
